# %%
import time, logging, sqlite3, sys, re
import pandas as pd 
import numpy as np 
import pickle as pkl
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from tqdm import tqdm
from sklearn.preprocessing import StandardScaler
import plotly.express as px
from sklearn.decomposition import PCA

# %%
create_table = """CREATE TABLE CONTEXT_WINDOWS (
               SENSE_NAME VARCHAR(10) NOT NULL,
               SEED_WORD VARCHAR(10) NOT NULL,
               CONTEXT_WINDOW VARCHAR(50) NOT NULL,
               SENTENCE TEXT NOT NULL
               );"""

# data = cursor.execute(create_table)
# conn.commit()

# %%
def convert(string):
    return string.replace("), (", "***").split("***")

def convert2(lst):
    return [tuple(map(replaceQuotes, itm.strip("()").split(","))) for itm in lst]

def replaceQuotes(string):
    return string.replace("'", "").strip()

def get_word_vectors(model, phrases_df):
        vectors = []
        dv = model.dv
        not_found = 0
        for idx, row in phrases_df.iterrows():
            try:
                vectors.append(dv[idx])
            except KeyError:
                print(idx, 'not found')
                not_found += 1
                continue

        n = len(vectors)
        print("n: " + str(n))
        print("not_found: " + str(not_found))

        return vectors   

    
def get_similarity_matrix(vectors):
    n = len(vectors)
    distances = np.zeros((len(vectors[:n]), len(vectors[:n])))

    for idx1, vec1 in enumerate(tqdm(vectors[:n])):
        for idx2, vec2 in enumerate(vectors[idx1:n]):
            if idx2 == 0:
                distances[idx1][idx1] = 0
                continue
            # calculate the pearson correlation 
            p = np.dot(vec1, vec2) / (np.linalg.norm(vec1) * np.linalg.norm(vec2))
            # calculate the distance between vectors 
            dist = abs(0.5 * (1 - p))

            distances[idx1][idx1 + idx2] = dist
            distances[idx1 + idx2][idx1] = dist

    return distances

def run_pca(distances, k):
    dist_matrix = pd.DataFrame(distances)
    x = dist_matrix.loc[:, ].values
    x = StandardScaler().fit_transform(x)
    reduction_model = PCA(n_components=k)
    pca = reduction_model.fit_transform(x)
    total_var = reduction_model.explained_variance_ratio_.sum() * 100
    logging.info("Total variance explained:" + str(total_var))
    return pca

class Corpus: 
    
    def __init__(self):
        self.corpus_df = pd.read_csv('../data/english_fiction_metadata.csv')
        self.context_windows_dict = '../data/full_corpus/context_windows_dict.pickle'
        self.context_windows_dict = {'sense_name': [], 'seed_word': [] , 'context_window': [], 'sentence': []}
        self.model_path = '../data/full_corpus/phrase_embedding_model_noun_adj_context_window_size_4.pickle'
        
        
    def train_phrases_model(self, ):
        start_time = time.time()
        data_set = self.read_file("../data/full_corpus/phrase_noun_adj_context_window_size_4.pickle")
        tagged_data = [TaggedDocument(d, [i]) for i, d in enumerate(data_set['test'].tolist())]
        model = Doc2Vec(tagged_data, vector_size = 20, window = 4, min_count = 1, epochs = 100)
        model.save(self.model_path)
        end_time = time.time()
        logging.info(end_time - start_time) 
    
    def read_file(self, input_path):
            logging.info('Opened: ' + input_path)
            with open(input_path, "rb") as f:
                input_obj = pkl.load(f)
                return input_obj     
            
    def save_file(self, output_obj, output_path):
        with open(output_path, 'wb') as f:
            pkl.dump(output_obj, f)
        logging.info('Saved to: ' + output_path)
            
    def save_context_windows(self,):
        vfunct = np.vectorize(self.insert_context_window_into_db)
        vfunct(self.corpus_df.cw_df_path)   
        
    def insert_context_window_into_db(self, cw_df_path):
        start_time = time.time()
        cw_df = self.read_file(cw_df_path)
        for idx, row in cw_df.iterrows():
            if row['context_window']:
                insert = """INSERT INTO CONTEXT_WINDOWS
                            (SENSE_NAME, SEED_WORD, CONTEXT_WINDOW, SENTENCE) 
                            VALUES (?, ?, ?, ?);"""
                data_tuple = (row['sense_name'], str(row['seed_word']), str(row['context_window']), str(row['sentence']))
                cursor.execute(insert, data_tuple)
                conn.commit()
        end_time = time.time()
        logging.info(end_time - start_time)
        
        
    def extract_noun_adjective_phrases(self,):
        sql_query = pd.read_sql_query("""SELECT * from CONTEXT_WINDOWS
                                 WHERE CONTEXT_WINDOW LIKE '%NOUN%'
                                 AND CONTEXT_WINDOW LIKE '%ADJ%'""", conn)
        df = pd.DataFrame(sql_query, columns = ['SENSE_NAME', 'SEED_WORD', 'CONTEXT_WINDOW', 'SENTENCE'])
        conn.close()
        df['test'] = df['CONTEXT_WINDOW'].str.strip('][')
        df['test'] = df['test'].apply(convert)
        df['test'] = df['test'].apply(convert2)
        df = df[df['test'].map(len) == 2]
        self.save_file(df, "../data/full_corpus/phrase_noun_adj_context_window_size_4.pickle")

# %%
# conn = sqlite3.connect('context_window.db')
# cursor = conn.cursor()
# pragma = """PRAGMA case_sensitive_like=ON;"""
# cursor.execute(pragma)

# %%
# corpus = Corpus()
# corpus.save_context_windows()
# corpus.extract_noun_adjective_phrases()
# corpus.train_phrases_model()

# %%
# cursor.execute('SELECT count(*) from CONTEXT_WINDOWS')
# cur_result = cursor.fetchone()
# print("There are " + str(cur_result) + " rows in the DB.")
# conn.close()

# %%
# cursor.execute("DELETE FROM CONTEXT_WINDOWS;")
# print('We have deleted', cursor.rowcount, 'records from the table.')
# conn.commit()
# conn.close()

# %%
model = Doc2Vec.load('../data/full_corpus/phrase_embedding_model_noun_adj_context_window_size_4.pickle')
# context_windows = read_file('../data/full_corpus/phrase_noun_adj_context_window_size_4.pickle')

# %%
context_window_list = context_windows['test'].tolist()
freq_list = [context_window_list.count(item) for item in context_window_list]
context_windows['freq'] = freq_list
context_windows.head()
# Out:
#    SENSE_NAME             SEED_WORD  \
# 0        hear     ('means', 'NOUN')
# 4       touch    ('strike', 'VERB')
# 5       touch  ('reaching', 'VERB')
# 7        hear     ('means', 'VERB')
# 12      sight      ('look', 'NOUN')
#
#                                    CONTEXT_WINDOW  \
# 0   [('thing', 'NOUN'), ('unprecedented', 'ADJ')]
# 4          [('quick', 'ADJ'), ('terror', 'NOUN')]
# 5      [('waters', 'NOUN'), ('revolving', 'ADJ')]
# 7           [('little', 'ADJ'), ('word', 'NOUN')]
# 12         [('regular', 'ADJ'), ('outs', 'NOUN')]
#
#                                              SENTENCE  \
# 0   [('here', 'ADV'), ('be', 'VERB'), ('it', 'PRON...
# 4   [('as', 'ADP'), ('if', 'ADP'), ('to', 'PART'),...
# 5   [('while', 'ADP'), ('the', 'DET'), ('two', 'NU...
# 7   [('what', 'NOUN'), ('means', 'VERB'), ('that',...
# 12  [('come', 'VERB'), ('down', 'PART'), (',', 'PU...
#
#                                      test  freq
# 0   [(thing, NOUN), (unprecedented, ADJ)]     4
# 4          [(quick, ADJ), (terror, NOUN)]     4
# 5      [(waters, NOUN), (revolving, ADJ)]     4
# 7           [(little, ADJ), (word, NOUN)]     8
# 12         [(regular, ADJ), (outs, NOUN)]     4

# %%
context_windows['SENSE_NAME'] = context_windows['SENSE_NAME'].astype(str)
context_windows['test'] = context_windows['test'].astype(str)
context_windows.head()
# Out:
#    SENSE_NAME             SEED_WORD  \
# 0        hear     ('means', 'NOUN')
# 4       touch    ('strike', 'VERB')
# 5       touch  ('reaching', 'VERB')
# 7        hear     ('means', 'VERB')
# 12      sight      ('look', 'NOUN')
#
#                                    CONTEXT_WINDOW  \
# 0   [('thing', 'NOUN'), ('unprecedented', 'ADJ')]
# 4          [('quick', 'ADJ'), ('terror', 'NOUN')]
# 5      [('waters', 'NOUN'), ('revolving', 'ADJ')]
# 7           [('little', 'ADJ'), ('word', 'NOUN')]
# 12         [('regular', 'ADJ'), ('outs', 'NOUN')]
#
#                                              SENTENCE  \
# 0   [('here', 'ADV'), ('be', 'VERB'), ('it', 'PRON...
# 4   [('as', 'ADP'), ('if', 'ADP'), ('to', 'PART'),...
# 5   [('while', 'ADP'), ('the', 'DET'), ('two', 'NU...
# 7   [('what', 'NOUN'), ('means', 'VERB'), ('that',...
# 12  [('come', 'VERB'), ('down', 'PART'), (',', 'PU...
#
#                                              test  freq
# 0   [('thing', 'NOUN'), ('unprecedented', 'ADJ')]     4
# 4          [('quick', 'ADJ'), ('terror', 'NOUN')]     4
# 5      [('waters', 'NOUN'), ('revolving', 'ADJ')]     4
# 7           [('little', 'ADJ'), ('word', 'NOUN')]     8
# 12         [('regular', 'ADJ'), ('outs', 'NOUN')]     4

# %%
context_windows.loc[[178072]]
# Out:
#        SENSE_NAME            SEED_WORD                       CONTEXT_WINDOW  \
# 178072      taste  ('bitterly', 'ADV')  [('old', 'ADJ'), ('woman', 'NOUN')]
#
#                                                  SENTENCE  \
# 178072  [('"', 'PUNCT'), ('that', 'DET'), ('is', 'VERB...
#
#                                        test  freq
# 178072  [('old', 'ADJ'), ('woman', 'NOUN')]    94

# %%
with open("context_windows.pickle", "rb") as f:
    context_windows = pkl.load(f)
context_windows.head()
# Out:
#   SENSE_NAME             SEED_WORD  \
# 0       hear     ('means', 'NOUN')
# 1      touch    ('strike', 'VERB')
# 2      touch  ('reaching', 'VERB')
# 3       hear     ('means', 'VERB')
# 4      sight      ('look', 'NOUN')
#
#                                   CONTEXT_WINDOW  \
# 0  [('thing', 'NOUN'), ('unprecedented', 'ADJ')]
# 1         [('quick', 'ADJ'), ('terror', 'NOUN')]
# 2     [('waters', 'NOUN'), ('revolving', 'ADJ')]
# 3          [('little', 'ADJ'), ('word', 'NOUN')]
# 4         [('regular', 'ADJ'), ('outs', 'NOUN')]
#
#                                             SENTENCE  \
# 0  [('here', 'ADV'), ('be', 'VERB'), ('it', 'PRON...
# 1  [('as', 'ADP'), ('if', 'ADP'), ('to', 'PART'),...
# 2  [('while', 'ADP'), ('the', 'DET'), ('two', 'NU...
# 3  [('what', 'NOUN'), ('means', 'VERB'), ('that',...
# 4  [('come', 'VERB'), ('down', 'PART'), (',', 'PU...
#
#                                             test  freq
# 0  [('thing', 'NOUN'), ('unprecedented', 'ADJ')]     4
# 1         [('quick', 'ADJ'), ('terror', 'NOUN')]     4
# 2     [('waters', 'NOUN'), ('revolving', 'ADJ')]     4
# 3          [('little', 'ADJ'), ('word', 'NOUN')]     8
# 4         [('regular', 'ADJ'), ('outs', 'NOUN')]     4

# %%
context_windows['freq'] = context_windows['freq'].astype(int)
# context_windows = context_windows.reset_index(drop=True)
frames = []
senses = ['sight', 'hear', 'touch', 'taste', 'smell']
for modality in senses:
    print(modality)
    subset = context_windows.loc[(context_windows['SENSE_NAME'] == modality)].drop_duplicates(subset=['test', 'SENSE_NAME'])
    subset = subset.nlargest(40,'freq')
    frames.append(subset)
    display(subset)
top_phrases_df = pd.concat(frames)
top_phrases_df.head()
# Out:
# sight
#       SENSE_NAME             SEED_WORD  \
# 392        sight      ('look', 'NOUN')
# 91         sight    ('looked', 'VERB')
# 753        sight     ('watch', 'VERB')
# 1060       sight      ('seen', 'VERB')
# 2608       sight   ('looking', 'VERB')
# 3875       sight      ('look', 'VERB')
# 2866       sight    ('looked', 'VERB')
# 1102       sight    ('looked', 'VERB')
# 1611       sight       ('eye', 'NOUN')
# 6666       sight    ('looked', 'VERB')
# 766        sight    ('looked', 'VERB')
# 2325       sight      ('seen', 'VERB')
# 4647       sight      ('look', 'VERB')
# 902        sight      ('look', 'VERB')
# 3442       sight   ('lookers', 'NOUN')
# 7418       sight       ('see', 'VERB')
# 6637       sight      ('eyes', 'NOUN')
# 1960       sight       ('saw', 'VERB')
# 7275       sight     ('watch', 'NOUN')
# 156        sight       ('eye', 'NOUN')
# 2179       sight       ('see', 'VERB')
# 12049      sight   ('looking', 'VERB')
# 2794       sight       ('saw', 'VERB')
# 8720       sight    ('looked', 'VERB')
# 11067      sight    ('looked', 'VERB')
# 1765       sight       ('see', 'VERB')
# 2977       sight   ('watched', 'VERB')
# 4152       sight      ('look', 'VERB')
# 4859       sight    ('looked', 'VERB')
# 8840       sight     ('watch', 'NOUN')
# 10424      sight      ('eyes', 'NOUN')
# 5869       sight       ('eye', 'NOUN')
# 3377       sight   ('peeping', 'VERB')
# 7215       sight  ('watching', 'VERB')
# 4976       sight  ('glancing', 'VERB')
# 4439       sight   ('staring', 'VERB')
# 6147       sight       ('see', 'VERB')
# 15661      sight       ('see', 'VERB')
# 12469      sight       ('saw', 'VERB')
# 4379       sight      ('gaze', 'NOUN')
#
#                                 CONTEXT_WINDOW  \
# 392          [('old', 'ADJ'), ('man', 'NOUN')]
# 91         [('young', 'ADJ'), ('man', 'NOUN')]
# 753       [('great', 'ADJ'), ('deal', 'NOUN')]
# 1060       [('good', 'ADJ'), ('deal', 'NOUN')]
# 2608       [('long', 'ADJ'), ('time', 'NOUN')]
# 3875      [('young', 'ADJ'), ('lady', 'NOUN')]
# 2866       [('old', 'ADJ'), ('woman', 'NOUN')]
# 1102     [('little', 'ADJ'), ('girl', 'NOUN')]
# 1611        [('old', 'ADJ'), ('lady', 'NOUN')]
# 6666       [('door', 'NOUN'), ('open', 'ADJ')]
# 766       [('old', 'ADJ'), ('friend', 'NOUN')]
# 2325     [('young', 'ADJ'), ('woman', 'NOUN')]
# 4647      [('young', 'ADJ'), ('girl', 'NOUN')]
# 902    [('old', 'ADJ'), ('gentleman', 'NOUN')]
# 3442       [('young', 'ADJ'), ('men', 'NOUN')]
# 7418      [('right', 'ADJ'), ('hand', 'NOUN')]
# 6637       [('left', 'ADJ'), ('hand', 'NOUN')]
# 1960       [('white', 'ADJ'), ('man', 'NOUN')]
# 7275      [('good', 'ADJ'), ('night', 'NOUN')]
# 156         [('dead', 'ADJ'), ('man', 'NOUN')]
# 2179      [('old', 'ADJ'), ('fellow', 'NOUN')]
# 12049      [('low', 'ADJ'), ('voice', 'NOUN')]
# 2794      [('little', 'ADJ'), ('way', 'NOUN')]
# 8720      [('little', 'ADJ'), ('man', 'NOUN')]
# 11067    [('second', 'ADJ'), ('time', 'NOUN')]
# 1765       [('way', 'NOUN'), ('clear', 'ADJ')]
# 2977    [('young', 'ADJ'), ('fellow', 'NOUN')]
# 4152   [('years', 'NOUN'), ('younger', 'ADJ')]
# 4859      [('white', 'ADJ'), ('face', 'NOUN')]
# 8840       [('pale', 'ADJ'), ('face', 'NOUN')]
# 10424       [('low', 'ADJ'), ('tone', 'NOUN')]
# 5869     [('good', 'ADJ'), ('things', 'NOUN')]
# 3377       [('open', 'ADJ'), ('door', 'NOUN')]
# 7215       [('half', 'ADJ'), ('hour', 'NOUN')]
# 4976      [('little', 'ADJ'), ('boy', 'NOUN')]
# 4439        [('good', 'ADJ'), ('man', 'NOUN')]
# 6147    [('young', 'ADJ'), ('people', 'NOUN')]
# 15661       [('glad', 'ADJ'), ('sir', 'NOUN')]
# 12469    [('little', 'ADJ'), ('room', 'NOUN')]
# 4379       [('blue', 'ADJ'), ('eyes', 'NOUN')]
#
#                                                 SENTENCE  \
# 392    [('"', 'PUNCT'), ('said', 'VERB'), ('hester', ...
# 91     [('she', 'PRON'), ('looked', 'VERB'), ('at', '...
# 753    [('it', 'PRON'), ("'s", 'VERB'), ('a', 'DET'),...
# 1060   [('she', 'PRON'), ('had', 'VERB'), ('seen', 'V...
# 2608   [('now', 'ADV'), ('he', 'PRON'), ('could', 'VE...
# 3875   [('"', 'PUNCT'), ('look', 'VERB'), ('at', 'ADP...
# 2866   [('she', 'PRON'), ('looked', 'VERB'), ('an', '...
# 1102   [('when', 'ADV'), ('dorothy', 'PROPN'), (',', ...
# 1611   [('tom', 'PROPN'), ('felt', 'VERB'), ('the', '...
# 6666   [('i', 'PRON'), ('flung', 'VERB'), ('the', 'DE...
# 766    [('thea', 'PROPN'), ('looked', 'VERB'), ('at',...
# 2325   [('anderssen', 'PROPN'), ('knew', 'VERB'), ('w...
# 4647   [('it', 'PRON'), ('is', 'VERB'), ('certain', '...
# 902    [('it', 'PRON'), ('sent', 'VERB'), ('a', 'DET'...
# 3442   [('among', 'ADP'), ('these', 'DET'), ('on', 'A...
# 7418   [('"', 'PUNCT'), ('did', 'VERB'), ('you', 'PRO...
# 6637   [('i', 'PRON'), ('heard', 'VERB'), ('some', 'D...
# 1960   [('i', 'PRON'), ('was', 'VERB'), ('twenty', 'N...
# 7275   [('the', 'DET'), ('elder', 'NOUN'), ('who', 'N...
# 156    [('the', 'DET'), ('pool', 'NOUN'), ('glittered...
# 2179   [('you', 'PRON'), ('see', 'VERB'), (',', 'PUNC...
# 12049  [('"', 'PUNCT'), ('she', 'PRON'), ('said', 'VE...
# 2794   [('he', 'PRON'), ('believed', 'VERB'), ('that'...
# 8720   [('"', 'PUNCT'), ('well', 'INTJ'), (',', 'PUNC...
# 11067  [('he', 'PRON'), ('looked', 'VERB'), ('at', 'A...
# 1765   [('"', 'PUNCT'), ('cousin', 'PROPN'), ('phoebe...
# 2977   [('he', 'PRON'), ('watched', 'VERB'), ('the', ...
# 4152   [('"', 'PUNCT'), ('i', 'PRON'), ('know', 'VERB...
# 4859   [('his', 'ADJ'), ('white', 'ADJ'), ('face', 'N...
# 8840   [('in', 'ADP'), ('the', 'DET'), ('darkness', '...
# 10424  [('"', 'PUNCT'), ('today', 'NOUN'), (',', 'PUN...
# 5869   [('you', 'PRON'), ('said', 'VERB'), ('he', 'PR...
# 3377   [('peeping', 'VERB'), ('into', 'ADP'), ('the',...
# 7215   [('it', 'PRON'), ('was', 'VERB'), ('a', 'DET')...
# 4976   [('once', 'ADV'), ('or', 'CCONJ'), ('twice', '...
# 4439   [('napoleon', 'PROPN'), (',', 'PUNCT'), ('on',...
# 6147   [('he', 'PRON'), ('could', 'VERB'), ('see', 'V...
# 15661  [('"', 'PUNCT'), ('i', 'PRON'), ('am', 'VERB')...
# 12469  [('he', 'PRON'), ('saw', 'VERB'), ('the', 'DET...
# 4379   [('the', 'DET'), ('hands', 'NOUN'), ('spread',...
#
#                                           test  freq
# 392          [('old', 'ADJ'), ('man', 'NOUN')]   370
# 91         [('young', 'ADJ'), ('man', 'NOUN')]   365
# 753       [('great', 'ADJ'), ('deal', 'NOUN')]   220
# 1060       [('good', 'ADJ'), ('deal', 'NOUN')]   215
# 2608       [('long', 'ADJ'), ('time', 'NOUN')]   207
# 3875      [('young', 'ADJ'), ('lady', 'NOUN')]   131
# 2866       [('old', 'ADJ'), ('woman', 'NOUN')]    94
# 1102     [('little', 'ADJ'), ('girl', 'NOUN')]    92
# 1611        [('old', 'ADJ'), ('lady', 'NOUN')]    69
# 6666       [('door', 'NOUN'), ('open', 'ADJ')]    67
# 766       [('old', 'ADJ'), ('friend', 'NOUN')]    65
# 2325     [('young', 'ADJ'), ('woman', 'NOUN')]    62
# 4647      [('young', 'ADJ'), ('girl', 'NOUN')]    57
# 902    [('old', 'ADJ'), ('gentleman', 'NOUN')]    54
# 3442       [('young', 'ADJ'), ('men', 'NOUN')]    53
# 7418      [('right', 'ADJ'), ('hand', 'NOUN')]    53
# 6637       [('left', 'ADJ'), ('hand', 'NOUN')]    52
# 1960       [('white', 'ADJ'), ('man', 'NOUN')]    51
# 7275      [('good', 'ADJ'), ('night', 'NOUN')]    51
# 156         [('dead', 'ADJ'), ('man', 'NOUN')]    48
# 2179      [('old', 'ADJ'), ('fellow', 'NOUN')]    45
# 12049      [('low', 'ADJ'), ('voice', 'NOUN')]    45
# 2794      [('little', 'ADJ'), ('way', 'NOUN')]    44
# 8720      [('little', 'ADJ'), ('man', 'NOUN')]    44
# 11067    [('second', 'ADJ'), ('time', 'NOUN')]    41
# 1765       [('way', 'NOUN'), ('clear', 'ADJ')]    40
# 2977    [('young', 'ADJ'), ('fellow', 'NOUN')]    40
# 4152   [('years', 'NOUN'), ('younger', 'ADJ')]    40
# 4859      [('white', 'ADJ'), ('face', 'NOUN')]    40
# 8840       [('pale', 'ADJ'), ('face', 'NOUN')]    39
# 10424       [('low', 'ADJ'), ('tone', 'NOUN')]    39
# 5869     [('good', 'ADJ'), ('things', 'NOUN')]    38
# 3377       [('open', 'ADJ'), ('door', 'NOUN')]    37
# 7215       [('half', 'ADJ'), ('hour', 'NOUN')]    36
# 4976      [('little', 'ADJ'), ('boy', 'NOUN')]    35
# 4439        [('good', 'ADJ'), ('man', 'NOUN')]    34
# 6147    [('young', 'ADJ'), ('people', 'NOUN')]    33
# 15661       [('glad', 'ADJ'), ('sir', 'NOUN')]    33
# 12469    [('little', 'ADJ'), ('room', 'NOUN')]    31
# 4379       [('blue', 'ADJ'), ('eyes', 'NOUN')]    30
# hear
#       SENSE_NAME              SEED_WORD  \
# 2314        hear      ('voice', 'NOUN')
# 1200        hear      ('silent', 'ADJ')
# 81          hear       ('mean', 'VERB')
# 702         hear    ('meaning', 'NOUN')
# 3559        hear   ('listened', 'VERB')
# 6361        hear      ('heard', 'VERB')
# 7645        hear   ('listened', 'VERB')
# 1117        hear     ('sounds', 'NOUN')
# 23202       hear       ('mean', 'VERB')
# 592         hear      ('heard', 'VERB')
# 23405       hear      ('heard', 'VERB')
# 3059        hear    ('meaning', 'VERB')
# 8491        hear       ('quiet', 'ADJ')
# 17038       hear      ('heard', 'VERB')
# 6027        hear       ('mean', 'VERB')
# 27982       hear      ('heard', 'VERB')
# 1149        hear        ('loud', 'ADJ')
# 1890        hear       ('hear', 'VERB')
# 1339        hear      ('means', 'VERB')
# 8931        hear      ('sound', 'NOUN')
# 18063       hear      ('heard', 'VERB')
# 1349        hear    ('silence', 'NOUN')
# 5056        hear      ('heard', 'VERB')
# 10081       hear  ('listening', 'VERB')
# 5316        hear      ('voice', 'NOUN')
# 14077       hear    ('meaning', 'NOUN')
# 14733       hear   ('silenced', 'VERB')
# 47574       hear   ('listened', 'VERB')
# 5472        hear      ('voice', 'NOUN')
# 23860       hear      ('heard', 'VERB')
# 4308        hear      ('heard', 'VERB')
# 61666       hear    ('hearing', 'VERB')
# 8098        hear     ('listen', 'VERB')
# 25303       hear  ('listening', 'NOUN')
# 46312       hear       ('quiet', 'ADJ')
# 225         hear       ('hear', 'VERB')
# 32835       hear      ('meant', 'VERB')
# 30043       hear    ('silence', 'NOUN')
# 1164        hear  ('articulate', 'ADJ')
# 2723        hear       ('hear', 'VERB')
#
#                                  CONTEXT_WINDOW  \
# 2314          [('old', 'ADJ'), ('man', 'NOUN')]
# 1200        [('young', 'ADJ'), ('man', 'NOUN')]
# 81         [('great', 'ADJ'), ('deal', 'NOUN')]
# 702         [('good', 'ADJ'), ('deal', 'NOUN')]
# 3559        [('long', 'ADJ'), ('time', 'NOUN')]
# 6361       [('young', 'ADJ'), ('lady', 'NOUN')]
# 7645        [('old', 'ADJ'), ('woman', 'NOUN')]
# 1117      [('little', 'ADJ'), ('girl', 'NOUN')]
# 23202        [('old', 'ADJ'), ('lady', 'NOUN')]
# 592         [('door', 'NOUN'), ('open', 'ADJ')]
# 23405      [('old', 'ADJ'), ('friend', 'NOUN')]
# 3059      [('young', 'ADJ'), ('woman', 'NOUN')]
# 8491       [('young', 'ADJ'), ('girl', 'NOUN')]
# 17038   [('old', 'ADJ'), ('gentleman', 'NOUN')]
# 6027        [('young', 'ADJ'), ('men', 'NOUN')]
# 27982      [('right', 'ADJ'), ('hand', 'NOUN')]
# 1149       [('good', 'ADJ'), ('night', 'NOUN')]
# 1890        [('white', 'ADJ'), ('man', 'NOUN')]
# 1339         [('dead', 'ADJ'), ('man', 'NOUN')]
# 8931        [('low', 'ADJ'), ('voice', 'NOUN')]
# 18063      [('old', 'ADJ'), ('fellow', 'NOUN')]
# 1349       [('little', 'ADJ'), ('way', 'NOUN')]
# 5056       [('little', 'ADJ'), ('man', 'NOUN')]
# 10081     [('second', 'ADJ'), ('time', 'NOUN')]
# 5316     [('young', 'ADJ'), ('fellow', 'NOUN')]
# 14077       [('way', 'NOUN'), ('clear', 'ADJ')]
# 14733      [('white', 'ADJ'), ('face', 'NOUN')]
# 47574   [('years', 'NOUN'), ('younger', 'ADJ')]
# 5472         [('low', 'ADJ'), ('tone', 'NOUN')]
# 23860       [('pale', 'ADJ'), ('face', 'NOUN')]
# 4308      [('good', 'ADJ'), ('things', 'NOUN')]
# 61666       [('open', 'ADJ'), ('door', 'NOUN')]
# 8098        [('half', 'ADJ'), ('hour', 'NOUN')]
# 25303      [('little', 'ADJ'), ('boy', 'NOUN')]
# 46312        [('good', 'ADJ'), ('man', 'NOUN')]
# 225          [('glad', 'ADJ'), ('sir', 'NOUN')]
# 32835    [('young', 'ADJ'), ('people', 'NOUN')]
# 30043     [('little', 'ADJ'), ('room', 'NOUN')]
# 1164      [('single', 'ADJ'), ('word', 'NOUN')]
# 2723   [('strange', 'ADJ'), ('things', 'NOUN')]
#
#                                                 SENTENCE  \
# 2314   [('then', 'ADV'), ('the', 'DET'), ('voice', 'N...
# 1200   [('the', 'DET'), ('young', 'ADJ'), ('man', 'NO...
# 81     [('that', 'DET'), ('will', 'VERB'), ('mean', '...
# 702    [('there', 'ADV'), ('was', 'VERB'), ('a', 'DET...
# 3559   [('"', 'PUNCT'), ('she', 'PRON'), ('asked', 'V...
# 6361   [('i', 'PRON'), ('was', 'VERB'), ('"', 'PUNCT'...
# 7645   [('richard', 'PROPN'), ('and', 'CCONJ'), ('mon...
# 1117   [('these', 'DET'), ('sounds', 'NOUN'), ('made'...
# 23202  [('"', 'PUNCT'), ('you', 'PRON'), ('mean', 'VE...
# 592    [('when', 'ADV'), ('she', 'PRON'), ('heard', '...
# 23405  [('when', 'ADV'), ('old', 'ADJ'), ('osborne', ...
# 3059   [('with', 'ADP'), ('regard', 'NOUN'), ('to', '...
# 8491   [('winterbourne', 'PROPN'), ('took', 'VERB'), ...
# 17038  [('"', 'PUNCT'), ('and', 'CCONJ'), ('yet', 'AD...
# 6027   [('young', 'ADJ'), ('men', 'NOUN'), ('do', 'VE...
# 27982  [('i', 'PRON'), ('was', 'VERB'), ('struck', 'V...
# 1149   [('the', 'DET'), ('stranger', 'NOUN'), ('then'...
# 1890   [('no', 'INTJ'), (',', 'PUNCT'), ('the', 'DET'...
# 1339   [('upon', 'ADP'), ('barsoom', 'PROPN'), (',', ...
# 8931   [('it', 'PRON'), ('is', 'VERB'), ('the', 'DET'...
# 18063  [('i', 'PRON'), ('heard', 'VERB'), ('the', 'DE...
# 1349   [('"', 'PUNCT'), ('you', 'PRON'), ('spared', '...
# 5056   [('so', 'ADV'), ('much', 'ADV'), ('the', 'DET'...
# 10081  [('a', 'DET'), ('second', 'ADJ'), ('time', 'NO...
# 5316   [('"', 'PUNCT'), ('these', 'DET'), ('few', 'AD...
# 14077  [('but', 'CCONJ'), ('in', 'ADP'), ('one', 'NUM...
# 14733  [('he----', 'PROPN'), ('"', 'PUNCT'), (' ', 'S...
# 47574  [('lady', 'PROPN'), ('holchester', 'PROPN'), (...
# 5472   [('well', 'INTJ'), (',', 'PUNCT'), ('i', 'PRON...
# 23860  [('she', 'PRON'), (' ', 'SPACE'), ('too', 'ADV...
# 4308   [('he', 'PRON'), ('remembered', 'VERB'), ('now...
# 61666  [('"', 'PUNCT'), ('perhaps', 'ADV'), ('so', 'A...
# 8098   [('i', 'PRON'), ('made', 'VERB'), ('him', 'PRO...
# 25303  [('it', 'PRON'), ('is', 'VERB'), ('curious', '...
# 46312  [('a', 'DET'), ('quiet', 'ADJ'), ('and', 'CCON...
# 225    [('"', 'PUNCT'), ('i', 'PRON'), ('am', 'VERB')...
# 32835  [('it', 'PRON'), ('seems', 'VERB'), ('to', 'AD...
# 30043  [('for', 'ADP'), ('a', 'DET'), ('little', 'ADJ...
# 1164   [('what', 'NOUN'), ('he', 'PRON'), ('said', 'V...
# 2723   [('"', 'PUNCT'), ('marshal', 'PROPN'), (',', '...
#
#                                            test  freq
# 2314          [('old', 'ADJ'), ('man', 'NOUN')]   370
# 1200        [('young', 'ADJ'), ('man', 'NOUN')]   365
# 81         [('great', 'ADJ'), ('deal', 'NOUN')]   220
# 702         [('good', 'ADJ'), ('deal', 'NOUN')]   215
# 3559        [('long', 'ADJ'), ('time', 'NOUN')]   207
# 6361       [('young', 'ADJ'), ('lady', 'NOUN')]   131
# 7645        [('old', 'ADJ'), ('woman', 'NOUN')]    94
# 1117      [('little', 'ADJ'), ('girl', 'NOUN')]    92
# 23202        [('old', 'ADJ'), ('lady', 'NOUN')]    69
# 592         [('door', 'NOUN'), ('open', 'ADJ')]    67
# 23405      [('old', 'ADJ'), ('friend', 'NOUN')]    65
# 3059      [('young', 'ADJ'), ('woman', 'NOUN')]    62
# 8491       [('young', 'ADJ'), ('girl', 'NOUN')]    57
# 17038   [('old', 'ADJ'), ('gentleman', 'NOUN')]    54
# 6027        [('young', 'ADJ'), ('men', 'NOUN')]    53
# 27982      [('right', 'ADJ'), ('hand', 'NOUN')]    53
# 1149       [('good', 'ADJ'), ('night', 'NOUN')]    51
# 1890        [('white', 'ADJ'), ('man', 'NOUN')]    51
# 1339         [('dead', 'ADJ'), ('man', 'NOUN')]    48
# 8931        [('low', 'ADJ'), ('voice', 'NOUN')]    45
# 18063      [('old', 'ADJ'), ('fellow', 'NOUN')]    45
# 1349       [('little', 'ADJ'), ('way', 'NOUN')]    44
# 5056       [('little', 'ADJ'), ('man', 'NOUN')]    44
# 10081     [('second', 'ADJ'), ('time', 'NOUN')]    41
# 5316     [('young', 'ADJ'), ('fellow', 'NOUN')]    40
# 14077       [('way', 'NOUN'), ('clear', 'ADJ')]    40
# 14733      [('white', 'ADJ'), ('face', 'NOUN')]    40
# 47574   [('years', 'NOUN'), ('younger', 'ADJ')]    40
# 5472         [('low', 'ADJ'), ('tone', 'NOUN')]    39
# 23860       [('pale', 'ADJ'), ('face', 'NOUN')]    39
# 4308      [('good', 'ADJ'), ('things', 'NOUN')]    38
# 61666       [('open', 'ADJ'), ('door', 'NOUN')]    37
# 8098        [('half', 'ADJ'), ('hour', 'NOUN')]    36
# 25303      [('little', 'ADJ'), ('boy', 'NOUN')]    35
# 46312        [('good', 'ADJ'), ('man', 'NOUN')]    34
# 225          [('glad', 'ADJ'), ('sir', 'NOUN')]    33
# 32835    [('young', 'ADJ'), ('people', 'NOUN')]    33
# 30043     [('little', 'ADJ'), ('room', 'NOUN')]    31
# 1164      [('single', 'ADJ'), ('word', 'NOUN')]    30
# 2723   [('strange', 'ADJ'), ('things', 'NOUN')]    30
# touch
#        SENSE_NAME             SEED_WORD  \
# 2953        touch  ('clinging', 'VERB')
# 2512        touch     ('touch', 'NOUN')
# 3094        touch      ('felt', 'VERB')
# 7394        touch      ('felt', 'VERB')
# 3546        touch  ('reaching', 'VERB')
# 22435       touch    ('kissed', 'VERB')
# 13170       touch      ('feel', 'VERB')
# 5068        touch      ('feel', 'VERB')
# 11263       touch   ('fingers', 'NOUN')
# 4526        touch   ('reached', 'VERB')
# 22947       touch  ('clinging', 'VERB')
# 3024        touch   ('pressed', 'VERB')
# 4672        touch     ('reach', 'NOUN')
# 30623       touch   ('hugging', 'VERB')
# 1935        touch   ('fingers', 'NOUN')
# 12685       touch    ('rubbed', 'VERB')
# 4562        touch      ('felt', 'VERB')
# 4107        touch      ('kiss', 'VERB')
# 10859       touch     ('feels', 'VERB')
# 21691       touch     ('touch', 'NOUN')
# 3109        touch   ('feeling', 'NOUN')
# 29138       touch      ('toes', 'NOUN')
# 815         touch      ('feel', 'VERB')
# 83577       touch    ('strike', 'VERB')
# 210         touch    ('kissed', 'VERB')
# 7967        touch    ('kissed', 'VERB')
# 44547       touch      ('felt', 'VERB')
# 91080       touch   ('touched', 'VERB')
# 61098       touch    ('kissed', 'VERB')
# 103671      touch  ('pressing', 'VERB')
# 72153       touch     ('reach', 'NOUN')
# 64383       touch     ('reach', 'VERB')
# 4663        touch    ('struck', 'VERB')
# 528         touch    ('struck', 'VERB')
# 11449       touch      ('kiss', 'VERB')
# 6189        touch      ('feel', 'VERB')
# 65807       touch      ('felt', 'VERB')
# 13867       touch   ('reached', 'VERB')
# 688         touch      ('felt', 'VERB')
# 20005       touch   ('feeling', 'NOUN')
#
#                                   CONTEXT_WINDOW  \
# 2953           [('old', 'ADJ'), ('man', 'NOUN')]
# 2512         [('young', 'ADJ'), ('man', 'NOUN')]
# 3094        [('great', 'ADJ'), ('deal', 'NOUN')]
# 7394         [('good', 'ADJ'), ('deal', 'NOUN')]
# 3546         [('long', 'ADJ'), ('time', 'NOUN')]
# 22435       [('young', 'ADJ'), ('lady', 'NOUN')]
# 13170        [('old', 'ADJ'), ('woman', 'NOUN')]
# 5068       [('little', 'ADJ'), ('girl', 'NOUN')]
# 11263         [('old', 'ADJ'), ('lady', 'NOUN')]
# 4526         [('door', 'NOUN'), ('open', 'ADJ')]
# 22947       [('old', 'ADJ'), ('friend', 'NOUN')]
# 3024       [('young', 'ADJ'), ('woman', 'NOUN')]
# 4672        [('young', 'ADJ'), ('girl', 'NOUN')]
# 30623    [('old', 'ADJ'), ('gentleman', 'NOUN')]
# 1935        [('right', 'ADJ'), ('hand', 'NOUN')]
# 12685        [('young', 'ADJ'), ('men', 'NOUN')]
# 4562         [('left', 'ADJ'), ('hand', 'NOUN')]
# 4107        [('good', 'ADJ'), ('night', 'NOUN')]
# 10859        [('white', 'ADJ'), ('man', 'NOUN')]
# 21691         [('dead', 'ADJ'), ('man', 'NOUN')]
# 3109         [('low', 'ADJ'), ('voice', 'NOUN')]
# 29138       [('old', 'ADJ'), ('fellow', 'NOUN')]
# 815         [('little', 'ADJ'), ('way', 'NOUN')]
# 83577       [('little', 'ADJ'), ('man', 'NOUN')]
# 210        [('second', 'ADJ'), ('time', 'NOUN')]
# 7967        [('white', 'ADJ'), ('face', 'NOUN')]
# 44547    [('years', 'NOUN'), ('younger', 'ADJ')]
# 91080     [('young', 'ADJ'), ('fellow', 'NOUN')]
# 61098        [('pale', 'ADJ'), ('face', 'NOUN')]
# 103671        [('low', 'ADJ'), ('tone', 'NOUN')]
# 72153      [('good', 'ADJ'), ('things', 'NOUN')]
# 64383        [('open', 'ADJ'), ('door', 'NOUN')]
# 4663         [('half', 'ADJ'), ('hour', 'NOUN')]
# 528     [('sudden', 'ADJ'), ('thought', 'NOUN')]
# 11449       [('little', 'ADJ'), ('boy', 'NOUN')]
# 6189          [('good', 'ADJ'), ('man', 'NOUN')]
# 65807     [('young', 'ADJ'), ('people', 'NOUN')]
# 13867      [('little', 'ADJ'), ('room', 'NOUN')]
# 688          [('dark', 'ADJ'), ('eyes', 'NOUN')]
# 20005     [('young', 'ADJ'), ('ladies', 'NOUN')]
#
#                                                  SENTENCE  \
# 2953    [('clinging', 'VERB'), ('to', 'ADP'), ('the', ...
# 2512    [('it', 'PRON'), ('would', 'VERB'), ('do', 'VE...
# 3094    [('she', 'PRON'), ('felt', 'VERB'), ('a', 'DET...
# 7394    [('he', 'PRON'), ('felt', 'VERB'), ('a', 'DET'...
# 3546    [('so', 'ADV'), ('spoke', 'VERB'), ('love', 'N...
# 22435   [('mr.', 'PROPN'), ('winkle', 'PROPN'), ('kiss...
# 13170   [('in', 'ADP'), ('the', 'DET'), ('train', 'NOU...
# 5068    [('whatever', 'ADJ'), ('i', 'PRON'), ('can', '...
# 11263   [('"', 'PUNCT'), ('yes', 'INTJ'), (',', 'PUNCT...
# 4526    [('it', 'PRON'), ('was', 'VERB'), ('never', 'A...
# 22947   [('but', 'CCONJ'), (',', 'PUNCT'), ('still', '...
# 3024    [('a', 'DET'), ('few', 'ADJ'), ('moments', 'NO...
# 4672    [('but', 'CCONJ'), ('the', 'DET'), ('horrible'...
# 30623   [('"', 'PUNCT'), (' ', 'SPACE'), ("'", 'PUNCT'...
# 1935    [('"', 'PUNCT'), ('place', 'PROPN'), ('the', '...
# 12685   [('the', 'DET'), ('young', 'ADJ'), ('men', 'NO...
# 4562    [('she', 'PRON'), ('felt', 'VERB'), ('with', '...
# 4107    [('may', 'VERB'), ('i', 'PRON'), ('kiss', 'VER...
# 10859   [('that', 'DET'), ('is', 'VERB'), ('how', 'ADV...
# 21691   [('that', 'ADP'), ('those', 'DET'), ('afflicte...
# 3109    [('"', 'PUNCT'), ('no', 'INTJ'), (',', 'PUNCT'...
# 29138   [('but', 'CCONJ'), ('the', 'DET'), ('old', 'AD...
# 815     [('"', 'PUNCT'), ('i', 'PRON'), ('did', 'VERB'...
# 83577   [('it', 'PRON'), ('seemed', 'VERB'), ('to', 'P...
# 210     [('he', 'PRON'), ('had', 'VERB'), ('also', 'AD...
# 7967    [('he', 'PRON'), ('kissed', 'VERB'), ('her', '...
# 44547   [('in', 'ADP'), ('petersburg', 'PROPN'), ('he'...
# 91080   [('this', 'DET'), ('touched', 'VERB'), ('the',...
# 61098   [('he', 'PRON'), ('kissed', 'VERB'), ('the', '...
# 103671  [('"', 'PUNCT'), ('your', 'ADJ'), ('majesty', ...
# 72153   [('"', 'PUNCT'), ('the', 'DET'), ('gods', 'NOU...
# 64383   [('to', 'PART'), ('reach', 'VERB'), ('the', 'D...
# 4663    [('the', 'DET'), ('half', 'ADJ'), ('-', 'PUNCT...
# 528     [('i', 'PRON'), ('was', 'VERB'), ('struck', 'V...
# 11449   [('"', 'PUNCT'), ('kiss', 'VERB'), ('me', 'PRO...
# 6189    [('i', 'PRON'), ('never', 'ADV'), ('was', 'VER...
# 65807   [('what', 'NOUN'), ('interest', 'NOUN'), ('the...
# 13867   [('"', 'PUNCT'), ('there', 'ADV'), (',', 'PUNC...
# 688     [('she', 'PRON'), ('felt', 'VERB'), ('all', 'A...
# 20005   [('no', 'DET'), ('hint', 'NOUN'), ('of', 'ADP'...
#
#                                             test  freq
# 2953           [('old', 'ADJ'), ('man', 'NOUN')]   370
# 2512         [('young', 'ADJ'), ('man', 'NOUN')]   365
# 3094        [('great', 'ADJ'), ('deal', 'NOUN')]   220
# 7394         [('good', 'ADJ'), ('deal', 'NOUN')]   215
# 3546         [('long', 'ADJ'), ('time', 'NOUN')]   207
# 22435       [('young', 'ADJ'), ('lady', 'NOUN')]   131
# 13170        [('old', 'ADJ'), ('woman', 'NOUN')]    94
# 5068       [('little', 'ADJ'), ('girl', 'NOUN')]    92
# 11263         [('old', 'ADJ'), ('lady', 'NOUN')]    69
# 4526         [('door', 'NOUN'), ('open', 'ADJ')]    67
# 22947       [('old', 'ADJ'), ('friend', 'NOUN')]    65
# 3024       [('young', 'ADJ'), ('woman', 'NOUN')]    62
# 4672        [('young', 'ADJ'), ('girl', 'NOUN')]    57
# 30623    [('old', 'ADJ'), ('gentleman', 'NOUN')]    54
# 1935        [('right', 'ADJ'), ('hand', 'NOUN')]    53
# 12685        [('young', 'ADJ'), ('men', 'NOUN')]    53
# 4562         [('left', 'ADJ'), ('hand', 'NOUN')]    52
# 4107        [('good', 'ADJ'), ('night', 'NOUN')]    51
# 10859        [('white', 'ADJ'), ('man', 'NOUN')]    51
# 21691         [('dead', 'ADJ'), ('man', 'NOUN')]    48
# 3109         [('low', 'ADJ'), ('voice', 'NOUN')]    45
# 29138       [('old', 'ADJ'), ('fellow', 'NOUN')]    45
# 815         [('little', 'ADJ'), ('way', 'NOUN')]    44
# 83577       [('little', 'ADJ'), ('man', 'NOUN')]    44
# 210        [('second', 'ADJ'), ('time', 'NOUN')]    41
# 7967        [('white', 'ADJ'), ('face', 'NOUN')]    40
# 44547    [('years', 'NOUN'), ('younger', 'ADJ')]    40
# 91080     [('young', 'ADJ'), ('fellow', 'NOUN')]    40
# 61098        [('pale', 'ADJ'), ('face', 'NOUN')]    39
# 103671        [('low', 'ADJ'), ('tone', 'NOUN')]    39
# 72153      [('good', 'ADJ'), ('things', 'NOUN')]    38
# 64383        [('open', 'ADJ'), ('door', 'NOUN')]    37
# 4663         [('half', 'ADJ'), ('hour', 'NOUN')]    36
# 528     [('sudden', 'ADJ'), ('thought', 'NOUN')]    35
# 11449       [('little', 'ADJ'), ('boy', 'NOUN')]    35
# 6189          [('good', 'ADJ'), ('man', 'NOUN')]    34
# 65807     [('young', 'ADJ'), ('people', 'NOUN')]    33
# 13867      [('little', 'ADJ'), ('room', 'NOUN')]    31
# 688          [('dark', 'ADJ'), ('eyes', 'NOUN')]    30
# 20005     [('young', 'ADJ'), ('ladies', 'NOUN')]    30
# taste
#        SENSE_NAME              SEED_WORD  \
# 6223        taste        ('sour', 'ADJ')
# 28255       taste     ('eating', 'VERB')
# 708         taste      ('taste', 'NOUN')
# 2193        taste        ('ate', 'VERB')
# 5930        taste        ('eat', 'VERB')
# 5535        taste     ('tastes', 'NOUN')
# 53930       taste    ('bitterly', 'ADV')
# 11573       taste       ('sweet', 'ADJ')
# 27635       taste      ('bitter', 'ADJ')
# 27644       taste  ('swallowed', 'VERB')
# 100910      taste    ('bitterly', 'ADV')
# 12877       taste       ('sweet', 'ADJ')
# 63322       taste    ('swallow', 'VERB')
# 42325       taste      ('meals', 'NOUN')
# 2261        taste       ('sweet', 'ADJ')
# 16375       taste        ('eat', 'VERB')
# 15122       taste     ('sweetly', 'ADV')
# 63149       taste    ('swallow', 'NOUN')
# 40838       taste    ('bitterly', 'ADV')
# 96739       taste       ('sweet', 'ADJ')
# 105875      taste       ('sweet', 'ADJ')
# 19555       taste       ('sweet', 'ADJ')
# 1108        taste        ('eat', 'VERB')
# 16416       taste        ('ate', 'VERB')
# 57122       taste      ('taste', 'NOUN')
# 86328       taste     ('eating', 'VERB')
# 46002       taste        ('eat', 'VERB')
# 17121       taste       ('sweet', 'ADJ')
# 47443       taste        ('ate', 'VERB')
# 105041      taste      ('bitter', 'ADJ')
# 17594       taste       ('meal', 'NOUN')
# 54632       taste       ('sweet', 'ADJ')
# 12890       taste       ('sweet', 'ADJ')
# 103685      taste      ('bitter', 'ADJ')
# 1100        taste       ('sweet', 'ADJ')
# 10657       taste       ('sweet', 'ADJ')
# 9806        taste    ('swallow', 'VERB')
# 36764       taste     ('eating', 'VERB')
# 2862        taste    ('swallow', 'VERB')
# 25019       taste        ('eat', 'VERB')
#
#                                   CONTEXT_WINDOW  \
# 6223           [('old', 'ADJ'), ('man', 'NOUN')]
# 28255        [('young', 'ADJ'), ('man', 'NOUN')]
# 708         [('great', 'ADJ'), ('deal', 'NOUN')]
# 2193         [('good', 'ADJ'), ('deal', 'NOUN')]
# 5930         [('long', 'ADJ'), ('time', 'NOUN')]
# 5535        [('young', 'ADJ'), ('lady', 'NOUN')]
# 53930        [('old', 'ADJ'), ('woman', 'NOUN')]
# 11573      [('little', 'ADJ'), ('girl', 'NOUN')]
# 27635         [('old', 'ADJ'), ('lady', 'NOUN')]
# 27644       [('old', 'ADJ'), ('friend', 'NOUN')]
# 100910     [('young', 'ADJ'), ('woman', 'NOUN')]
# 12877       [('young', 'ADJ'), ('girl', 'NOUN')]
# 63322    [('old', 'ADJ'), ('gentleman', 'NOUN')]
# 42325        [('left', 'ADJ'), ('hand', 'NOUN')]
# 2261        [('good', 'ADJ'), ('night', 'NOUN')]
# 16375        [('white', 'ADJ'), ('man', 'NOUN')]
# 15122        [('low', 'ADJ'), ('voice', 'NOUN')]
# 63149       [('old', 'ADJ'), ('fellow', 'NOUN')]
# 40838       [('little', 'ADJ'), ('man', 'NOUN')]
# 96739     [('young', 'ADJ'), ('fellow', 'NOUN')]
# 105875      [('white', 'ADJ'), ('face', 'NOUN')]
# 19555        [('pale', 'ADJ'), ('face', 'NOUN')]
# 1108       [('good', 'ADJ'), ('things', 'NOUN')]
# 16416       [('little', 'ADJ'), ('boy', 'NOUN')]
# 57122         [('good', 'ADJ'), ('man', 'NOUN')]
# 86328     [('young', 'ADJ'), ('people', 'NOUN')]
# 46002      [('little', 'ADJ'), ('room', 'NOUN')]
# 17121     [('young', 'ADJ'), ('ladies', 'NOUN')]
# 47443        [('blue', 'ADJ'), ('eyes', 'NOUN')]
# 105041  [('strange', 'ADJ'), ('things', 'NOUN')]
# 17594      [('little', 'ADJ'), ('time', 'NOUN')]
# 54632      [('clear', 'ADJ'), ('voice', 'NOUN')]
# 12890        [('poor', 'ADJ'), ('girl', 'NOUN')]
# 103685      [('sweet', 'ADJ'), ('face', 'NOUN')]
# 1100        [('soft', 'ADJ'), ('voice', 'NOUN')]
# 10657        [('fresh', 'ADJ'), ('air', 'NOUN')]
# 9806        [('half', 'ADJ'), ('dozen', 'NOUN')]
# 36764     [('little', 'ADJ'), ('thing', 'NOUN')]
# 2862      [('great', 'ADJ'), ('things', 'NOUN')]
# 25019         [('sick', 'ADJ'), ('man', 'NOUN')]
#
#                                                  SENTENCE  \
# 6223    [('now', 'ADV'), ('i', 'PRON'), ('am', 'VERB')...
# 28255   [('in', 'ADP'), ('this', 'DET'), ('order', 'NO...
# 708     [('she', 'PRON'), ('has', 'VERB'), ('a', 'DET'...
# 2193    [('if', 'ADP'), ('they', 'PRON'), ('ate', 'VER...
# 5930    [('he', 'PRON'), ('thought', 'VERB'), ('that',...
# 5535    [('you', 'PRON'), ('have', 'VERB'), ('not', 'A...
# 53930   [('"', 'PUNCT'), ('that', 'DET'), ('is', 'VERB...
# 11573   [('"', 'PUNCT'), ('who', 'NOUN'), ('could', 'V...
# 27635   [('she', 'PRON'), ('was', 'VERB'), ('such', 'A...
# 27644   [('he', 'PRON'), ('dropped', 'VERB'), ('the', ...
# 100910  [("'", 'PUNCT'), ('when', 'ADV'), ('tom', 'PRO...
# 12877   [('behold', 'ADV'), (',', 'PUNCT'), ('in', 'AD...
# 63322   [('"', 'PUNCT'), ('well', 'INTJ'), (',', 'PUNC...
# 42325   [('he', 'PRON'), ('is', 'VERB'), ('quite', 'AD...
# 2261    [('when', 'ADV'), ('they', 'PRON'), ('separate...
# 16375   [('then', 'ADV'), ('we', 'PRON'), ('eat', 'VER...
# 15122   [('then', 'ADV'), ('travis', 'PROPN'), ('said'...
# 63149   [('old', 'PROPN'), ('charleys', 'PROPN'), ('"'...
# 40838   [('"', 'PUNCT'), ('yes', 'INTJ'), (',', 'PUNCT...
# 96739   [('well', 'INTJ'), (',', 'PUNCT'), ('"', 'PUNC...
# 105875  [('and', 'CCONJ'), ('yet', 'ADV'), ('...', 'PU...
# 19555   [('we', 'PRON'), ('can', 'VERB'), ('see', 'VER...
# 1108    [('five', 'NUM'), ('little', 'ADJ'), ('fiddler...
# 16416   [('he', 'PRON'), ('frowned', 'VERB'), (',', 'P...
# 57122   [('the', 'DET'), ('king', 'NOUN'), ('not', 'AD...
# 86328   [(',', 'PUNCT'), ('that', 'DET'), ('is', 'VERB...
# 46002   [('an', 'DET'), ("'", 'PUNCT'), (',', 'PUNCT')...
# 17121   [('at', 'ADP'), ('length', 'NOUN'), ('the', 'D...
# 47443   [('he', 'PRON'), ('went', 'VERB'), ('forth', '...
# 105041  [('"', 'PUNCT'), ('ay', 'INTJ'), (',', 'PUNCT'...
# 17594   [('he', 'PRON'), ('would', 'VERB'), ('come', '...
# 54632   [("'", 'PUNCT'), ('yes', 'INTJ'), (',', 'PUNCT...
# 12890   [('what', 'NOUN'), ('did', 'VERB'), ('that', '...
# 103685  [('he', 'PRON'), (',', 'PUNCT'), ('therefore',...
# 1100    [('"', 'PUNCT'), ('you', 'PRON'), ('are', 'VER...
# 10657   [('but', 'CCONJ'), ('we', 'PRON'), ('came', 'V...
# 9806    [('our', 'ADJ'), ('mississippi', 'PROPN'), ('w...
# 36764   [('stupid', 'ADJ'), ('little', 'ADJ'), ('thing...
# 2862    [('monseigneur', 'PROPN'), ('could', 'VERB'), ...
# 25019   [('and', 'CCONJ'), ('there', 'ADV'), ('was', '...
#
#                                             test  freq
# 6223           [('old', 'ADJ'), ('man', 'NOUN')]   370
# 28255        [('young', 'ADJ'), ('man', 'NOUN')]   365
# 708         [('great', 'ADJ'), ('deal', 'NOUN')]   220
# 2193         [('good', 'ADJ'), ('deal', 'NOUN')]   215
# 5930         [('long', 'ADJ'), ('time', 'NOUN')]   207
# 5535        [('young', 'ADJ'), ('lady', 'NOUN')]   131
# 53930        [('old', 'ADJ'), ('woman', 'NOUN')]    94
# 11573      [('little', 'ADJ'), ('girl', 'NOUN')]    92
# 27635         [('old', 'ADJ'), ('lady', 'NOUN')]    69
# 27644       [('old', 'ADJ'), ('friend', 'NOUN')]    65
# 100910     [('young', 'ADJ'), ('woman', 'NOUN')]    62
# 12877       [('young', 'ADJ'), ('girl', 'NOUN')]    57
# 63322    [('old', 'ADJ'), ('gentleman', 'NOUN')]    54
# 42325        [('left', 'ADJ'), ('hand', 'NOUN')]    52
# 2261        [('good', 'ADJ'), ('night', 'NOUN')]    51
# 16375        [('white', 'ADJ'), ('man', 'NOUN')]    51
# 15122        [('low', 'ADJ'), ('voice', 'NOUN')]    45
# 63149       [('old', 'ADJ'), ('fellow', 'NOUN')]    45
# 40838       [('little', 'ADJ'), ('man', 'NOUN')]    44
# 96739     [('young', 'ADJ'), ('fellow', 'NOUN')]    40
# 105875      [('white', 'ADJ'), ('face', 'NOUN')]    40
# 19555        [('pale', 'ADJ'), ('face', 'NOUN')]    39
# 1108       [('good', 'ADJ'), ('things', 'NOUN')]    38
# 16416       [('little', 'ADJ'), ('boy', 'NOUN')]    35
# 57122         [('good', 'ADJ'), ('man', 'NOUN')]    34
# 86328     [('young', 'ADJ'), ('people', 'NOUN')]    33
# 46002      [('little', 'ADJ'), ('room', 'NOUN')]    31
# 17121     [('young', 'ADJ'), ('ladies', 'NOUN')]    30
# 47443        [('blue', 'ADJ'), ('eyes', 'NOUN')]    30
# 105041  [('strange', 'ADJ'), ('things', 'NOUN')]    30
# 17594      [('little', 'ADJ'), ('time', 'NOUN')]    29
# 54632      [('clear', 'ADJ'), ('voice', 'NOUN')]    29
# 12890        [('poor', 'ADJ'), ('girl', 'NOUN')]    28
# 103685      [('sweet', 'ADJ'), ('face', 'NOUN')]    28
# 1100        [('soft', 'ADJ'), ('voice', 'NOUN')]    27
# 10657        [('fresh', 'ADJ'), ('air', 'NOUN')]    27
# 9806        [('half', 'ADJ'), ('dozen', 'NOUN')]    26
# 36764     [('little', 'ADJ'), ('thing', 'NOUN')]    26
# 2862      [('great', 'ADJ'), ('things', 'NOUN')]    25
# 25019         [('sick', 'ADJ'), ('man', 'NOUN')]    25
# smell
#        SENSE_NAME                SEED_WORD  \
# 66687       smell         ('nose', 'NOUN')
# 45653       smell     ('breathed', 'VERB')
# 7578        smell        ('smoke', 'VERB')
# 32809       smell        ('smell', 'NOUN')
# 10809       smell      ('breathe', 'VERB')
# 8004        smell      ('perfume', 'NOUN')
# 46057       smell     ('breathed', 'VERB')
# 29300       smell    ('breathing', 'NOUN')
# 47875       smell      ('breathe', 'VERB')
# 106141      smell        ('smoke', 'VERB')
# 64410       smell       ('smells', 'VERB')
# 93472       smell         ('nose', 'NOUN')
# 66202       smell         ('nose', 'NOUN')
# 44080       smell     ('breathed', 'VERB')
# 84578       smell        ('smoke', 'VERB')
# 2621        smell      ('snuffed', 'VERB')
# 8732        smell      ('sniffed', 'VERB')
# 55545       smell        ('smoke', 'NOUN')
# 6679        smell        ('smoke', 'VERB')
# 45316       smell       ('smoked', 'VERB')
# 98656       smell      ('smoking', 'NOUN')
# 16834       smell        ('smell', 'VERB')
# 29145       smell     ('aspiring', 'VERB')
# 86740       smell         ('puffy', 'ADJ')
# 49593       smell    ('breathing', 'NOUN')
# 1135        smell      ('sniffed', 'VERB')
# 43551       smell         ('nose', 'NOUN')
# 94449       smell      ('smoking', 'NOUN')
# 7485        smell      ('smoking', 'NOUN')
# 44441       smell    ('breathing', 'VERB')
# 84479       smell        ('smell', 'VERB')
# 18956       smell    ('breathing', 'VERB')
# 38257       smell  ('aspirations', 'NOUN')
# 42156       smell     ('breathed', 'VERB')
# 21836       smell         ('puffy', 'ADJ')
# 102483      smell    ('breathing', 'NOUN')
# 20252       smell       ('puffed', 'VERB')
# 36132       smell       ('smoker', 'NOUN')
# 4802        smell     ('breathed', 'VERB')
# 6271        smell         ('nose', 'NOUN')
#
#                                    CONTEXT_WINDOW  \
# 66687           [('old', 'ADJ'), ('man', 'NOUN')]
# 45653         [('young', 'ADJ'), ('man', 'NOUN')]
# 7578         [('great', 'ADJ'), ('deal', 'NOUN')]
# 32809         [('good', 'ADJ'), ('deal', 'NOUN')]
# 10809         [('long', 'ADJ'), ('time', 'NOUN')]
# 8004         [('young', 'ADJ'), ('lady', 'NOUN')]
# 46057       [('little', 'ADJ'), ('girl', 'NOUN')]
# 29300          [('old', 'ADJ'), ('lady', 'NOUN')]
# 47875       [('young', 'ADJ'), ('woman', 'NOUN')]
# 106141    [('old', 'ADJ'), ('gentleman', 'NOUN')]
# 64410        [('good', 'ADJ'), ('night', 'NOUN')]
# 93472         [('white', 'ADJ'), ('man', 'NOUN')]
# 66202          [('dead', 'ADJ'), ('man', 'NOUN')]
# 44080         [('low', 'ADJ'), ('voice', 'NOUN')]
# 84578        [('old', 'ADJ'), ('fellow', 'NOUN')]
# 2621         [('little', 'ADJ'), ('man', 'NOUN')]
# 8732         [('little', 'ADJ'), ('way', 'NOUN')]
# 55545         [('pale', 'ADJ'), ('face', 'NOUN')]
# 6679          [('open', 'ADJ'), ('door', 'NOUN')]
# 45316         [('half', 'ADJ'), ('hour', 'NOUN')]
# 98656          [('good', 'ADJ'), ('man', 'NOUN')]
# 16834       [('little', 'ADJ'), ('room', 'NOUN')]
# 29145      [('young', 'ADJ'), ('ladies', 'NOUN')]
# 86740         [('blue', 'ADJ'), ('eyes', 'NOUN')]
# 49593       [('little', 'ADJ'), ('time', 'NOUN')]
# 1135          [('fresh', 'ADJ'), ('air', 'NOUN')]
# 43551       [('little', 'ADJ'), ('hand', 'NOUN')]
# 94449        [('half', 'ADJ'), ('dozen', 'NOUN')]
# 7485        [('open', 'ADJ'), ('window', 'NOUN')]
# 44441          [('sick', 'ADJ'), ('man', 'NOUN')]
# 84479         [('white', 'ADJ'), ('men', 'NOUN')]
# 18956   [('beautiful', 'ADJ'), ('woman', 'NOUN')]
# 38257          [('poor', 'ADJ'), ('man', 'NOUN')]
# 42156       [('long', 'ADJ'), ('breath', 'NOUN')]
# 21836       [('little', 'ADJ'), ('eyes', 'NOUN')]
# 102483       [('deep', 'ADJ'), ('voice', 'NOUN')]
# 20252           [('big', 'ADJ'), ('man', 'NOUN')]
# 36132        [('heart', 'NOUN'), ('good', 'ADJ')]
# 4802         [('open', 'ADJ'), ('mouth', 'NOUN')]
# 6271         [('plain', 'ADJ'), ('face', 'NOUN')]
#
#                                                  SENTENCE  \
# 66687   [('she', 'PRON'), ('withdrew', 'VERB'), ('her'...
# 45653   [('"', 'PUNCT'), ('parkenstacker', 'PROPN'), (...
# 7578    [('i', 'PRON'), ('smoke', 'VERB'), ('a', 'DET'...
# 32809   [('"', 'PUNCT'), ('a', 'DET'), ('person', 'NOU...
# 10809   [('i', 'PRON'), ('could', 'VERB'), ("n't", 'AD...
# 8004    [('the', 'DET'), ('perfume', 'NOUN'), ('of', '...
# 46057   [('"', 'PUNCT'), ('oh', 'INTJ'), (',', 'PUNCT'...
# 29300   [('he', 'PRON'), ('wears', 'VERB'), ('indiarub...
# 47875   [('but', 'CCONJ'), ('from', 'ADP'), ('the', 'D...
# 106141  [('inevitably', 'ADV'), ('the', 'DET'), ('old'...
# 64410   [('she', 'PRON'), ('smells', 'VERB'), ('good',...
# 93472   [('a', 'DET'), ('white', 'ADJ'), ('man', 'NOUN...
# 66202   [('you', 'PRON'), ('smell', 'VERB'), ('this', ...
# 44080   [('it', 'PRON'), ('approached', 'VERB'), ('the...
# 84578   [('and', 'CCONJ'), ('one', 'NUM'), ('night', '...
# 2621    [('the', 'DET'), ('great', 'ADJ'), ('beast', '...
# 8732    [('she', 'PRON'), ('sniffed', 'VERB'), ('in', ...
# 55545   [('may', 'VERB'), ('i', 'PRON'), ('take', 'VER...
# 6679    [('then', 'ADV'), ('he', 'PRON'), ('lit', 'VER...
# 45316   [('he', 'PRON'), ('smoked', 'VERB'), ('for', '...
# 98656   [('smoking', 'NOUN'), ('is', 'VERB'), ('the', ...
# 16834   [('she', 'PRON'), ('could', 'VERB'), ('smell',...
# 29145   [('aspiring', 'VERB'), ('young', 'ADJ'), ('lad...
# 86740   [('his', 'ADJ'), ('hair', 'NOUN'), ('was', 'VE...
# 49593   [('give', 'VERB'), ('me', 'PRON'), ('a', 'DET'...
# 1135    [('as', 'ADP'), ('for', 'ADP'), ('the', 'DET')...
# 43551   [('i', 'PRON'), ('told', 'VERB'), ('him', 'PRO...
# 94449   [('justice', 'PROPN'), ('hare', 'PROPN'), ('wa...
# 7485    [('it', 'PRON'), ('was', 'VERB'), ('a', 'DET')...
# 44441   [('the', 'DET'), ('feet', 'NOUN'), ('were', 'V...
# 84479   [('the', 'DET'), ('pine', 'ADJ'), ('splinters'...
# 18956   [('she', 'PRON'), ('was', 'VERB'), ('standing'...
# 38257   [('however', 'ADV'), (',', 'PUNCT'), ('such', ...
# 42156   [('she', 'PRON'), ('breathed', 'VERB'), ('a', ...
# 21836   [('they', 'PRON'), ('looked', 'VERB'), ('fairl...
# 102483  [('there', 'ADV'), ('was', 'VERB'), ('a', 'DET...
# 20252   [('then', 'ADV'), ('a', 'DET'), ('big', 'ADJ')...
# 36132   [('he', 'PRON'), ('sighed', 'VERB'), ('with', ...
# 4802    [('marius', 'PROPN'), ("'", 'PART'), ('eyelids...
# 6271    [('rosanna', 'PROPN'), ('spearman', 'PROPN'), ...
#
#                                              test  freq
# 66687           [('old', 'ADJ'), ('man', 'NOUN')]   370
# 45653         [('young', 'ADJ'), ('man', 'NOUN')]   365
# 7578         [('great', 'ADJ'), ('deal', 'NOUN')]   220
# 32809         [('good', 'ADJ'), ('deal', 'NOUN')]   215
# 10809         [('long', 'ADJ'), ('time', 'NOUN')]   207
# 8004         [('young', 'ADJ'), ('lady', 'NOUN')]   131
# 46057       [('little', 'ADJ'), ('girl', 'NOUN')]    92
# 29300          [('old', 'ADJ'), ('lady', 'NOUN')]    69
# 47875       [('young', 'ADJ'), ('woman', 'NOUN')]    62
# 106141    [('old', 'ADJ'), ('gentleman', 'NOUN')]    54
# 64410        [('good', 'ADJ'), ('night', 'NOUN')]    51
# 93472         [('white', 'ADJ'), ('man', 'NOUN')]    51
# 66202          [('dead', 'ADJ'), ('man', 'NOUN')]    48
# 44080         [('low', 'ADJ'), ('voice', 'NOUN')]    45
# 84578        [('old', 'ADJ'), ('fellow', 'NOUN')]    45
# 2621         [('little', 'ADJ'), ('man', 'NOUN')]    44
# 8732         [('little', 'ADJ'), ('way', 'NOUN')]    44
# 55545         [('pale', 'ADJ'), ('face', 'NOUN')]    39
# 6679          [('open', 'ADJ'), ('door', 'NOUN')]    37
# 45316         [('half', 'ADJ'), ('hour', 'NOUN')]    36
# 98656          [('good', 'ADJ'), ('man', 'NOUN')]    34
# 16834       [('little', 'ADJ'), ('room', 'NOUN')]    31
# 29145      [('young', 'ADJ'), ('ladies', 'NOUN')]    30
# 86740         [('blue', 'ADJ'), ('eyes', 'NOUN')]    30
# 49593       [('little', 'ADJ'), ('time', 'NOUN')]    29
# 1135          [('fresh', 'ADJ'), ('air', 'NOUN')]    27
# 43551       [('little', 'ADJ'), ('hand', 'NOUN')]    27
# 94449        [('half', 'ADJ'), ('dozen', 'NOUN')]    26
# 7485        [('open', 'ADJ'), ('window', 'NOUN')]    25
# 44441          [('sick', 'ADJ'), ('man', 'NOUN')]    25
# 84479         [('white', 'ADJ'), ('men', 'NOUN')]    23
# 18956   [('beautiful', 'ADJ'), ('woman', 'NOUN')]    22
# 38257          [('poor', 'ADJ'), ('man', 'NOUN')]    21
# 42156       [('long', 'ADJ'), ('breath', 'NOUN')]    20
# 21836       [('little', 'ADJ'), ('eyes', 'NOUN')]    19
# 102483       [('deep', 'ADJ'), ('voice', 'NOUN')]    19
# 20252           [('big', 'ADJ'), ('man', 'NOUN')]    18
# 36132        [('heart', 'NOUN'), ('good', 'ADJ')]    18
# 4802         [('open', 'ADJ'), ('mouth', 'NOUN')]    17
# 6271         [('plain', 'ADJ'), ('face', 'NOUN')]    17
#      SENSE_NAME            SEED_WORD                        CONTEXT_WINDOW  \
# 392       sight     ('look', 'NOUN')     [('old', 'ADJ'), ('man', 'NOUN')]
# 91        sight   ('looked', 'VERB')   [('young', 'ADJ'), ('man', 'NOUN')]
# 753       sight    ('watch', 'VERB')  [('great', 'ADJ'), ('deal', 'NOUN')]
# 1060      sight     ('seen', 'VERB')   [('good', 'ADJ'), ('deal', 'NOUN')]
# 2608      sight  ('looking', 'VERB')   [('long', 'ADJ'), ('time', 'NOUN')]
#
#                                                SENTENCE  \
# 392   [('"', 'PUNCT'), ('said', 'VERB'), ('hester', ...
# 91    [('she', 'PRON'), ('looked', 'VERB'), ('at', '...
# 753   [('it', 'PRON'), ("'s", 'VERB'), ('a', 'DET'),...
# 1060  [('she', 'PRON'), ('had', 'VERB'), ('seen', 'V...
# 2608  [('now', 'ADV'), ('he', 'PRON'), ('could', 'VE...
#
#                                       test  freq
# 392      [('old', 'ADJ'), ('man', 'NOUN')]   370
# 91     [('young', 'ADJ'), ('man', 'NOUN')]   365
# 753   [('great', 'ADJ'), ('deal', 'NOUN')]   220
# 1060   [('good', 'ADJ'), ('deal', 'NOUN')]   215
# 2608   [('long', 'ADJ'), ('time', 'NOUN')]   207

# %%
phrase_vectors = get_word_vectors(model, top_phrases_df)
# Out:
# n: 200
# not_found: 0

# %%
similarity_matrix = get_similarity_matrix(phrase_vectors)
# Out:
# 100%|██████████| 200/200 [00:00<00:00, 239.12it/s]

# %%
pca = run_pca(similarity_matrix, 2)

# %%
principalDf = pd.DataFrame(data = pca, columns = ['principal component 1', 'principal component 2'])

# %%
principalDf.shape
# Out:
# (200, 2)

# %%
principalDf.head()
# Out:
#    principal component 1  principal component 2
# 0              -9.943266              -0.374705
# 1             -10.418727              -1.546303
# 2               2.713349               5.346510
# 3               4.658481               4.467498
# 4               7.941022               3.130614

# %%
top_phrases_df = top_phrases_df.reset_index(drop=True)
display(top_phrases_df)
# Out:
#     SENSE_NAME              SEED_WORD                        CONTEXT_WINDOW  \
# 0        sight       ('look', 'NOUN')     [('old', 'ADJ'), ('man', 'NOUN')]
# 1        sight     ('looked', 'VERB')   [('young', 'ADJ'), ('man', 'NOUN')]
# 2        sight      ('watch', 'VERB')  [('great', 'ADJ'), ('deal', 'NOUN')]
# 3        sight       ('seen', 'VERB')   [('good', 'ADJ'), ('deal', 'NOUN')]
# 4        sight    ('looking', 'VERB')   [('long', 'ADJ'), ('time', 'NOUN')]
# ..         ...                    ...                                   ...
# 195      smell  ('breathing', 'NOUN')  [('deep', 'ADJ'), ('voice', 'NOUN')]
# 196      smell     ('puffed', 'VERB')     [('big', 'ADJ'), ('man', 'NOUN')]
# 197      smell     ('smoker', 'NOUN')  [('heart', 'NOUN'), ('good', 'ADJ')]
# 198      smell   ('breathed', 'VERB')  [('open', 'ADJ'), ('mouth', 'NOUN')]
# 199      smell       ('nose', 'NOUN')  [('plain', 'ADJ'), ('face', 'NOUN')]
#
#                                               SENTENCE  \
# 0    [('"', 'PUNCT'), ('said', 'VERB'), ('hester', ...
# 1    [('she', 'PRON'), ('looked', 'VERB'), ('at', '...
# 2    [('it', 'PRON'), ("'s", 'VERB'), ('a', 'DET'),...
# 3    [('she', 'PRON'), ('had', 'VERB'), ('seen', 'V...
# 4    [('now', 'ADV'), ('he', 'PRON'), ('could', 'VE...
# ..                                                 ...
# 195  [('there', 'ADV'), ('was', 'VERB'), ('a', 'DET...
# 196  [('then', 'ADV'), ('a', 'DET'), ('big', 'ADJ')...
# 197  [('he', 'PRON'), ('sighed', 'VERB'), ('with', ...
# 198  [('marius', 'PROPN'), ("'", 'PART'), ('eyelids...
# 199  [('rosanna', 'PROPN'), ('spearman', 'PROPN'), ...
#
#                                      test  freq
# 0       [('old', 'ADJ'), ('man', 'NOUN')]   370
# 1     [('young', 'ADJ'), ('man', 'NOUN')]   365
# 2    [('great', 'ADJ'), ('deal', 'NOUN')]   220
# 3     [('good', 'ADJ'), ('deal', 'NOUN')]   215
# 4     [('long', 'ADJ'), ('time', 'NOUN')]   207
# ..                                    ...   ...
# 195  [('deep', 'ADJ'), ('voice', 'NOUN')]    19
# 196     [('big', 'ADJ'), ('man', 'NOUN')]    18
# 197  [('heart', 'NOUN'), ('good', 'ADJ')]    18
# 198  [('open', 'ADJ'), ('mouth', 'NOUN')]    17
# 199  [('plain', 'ADJ'), ('face', 'NOUN')]    17
#
# [200 rows x 6 columns]

# %%
finalDf = pd.concat([principalDf, top_phrases_df[['SENSE_NAME', 'SEED_WORD', 'test', 'freq', 'SENTENCE']]], axis = 1)
finalDf.head()
# Out:
#    principal component 1  principal component 2 SENSE_NAME  \
# 0              -9.943266              -0.374705      sight
# 1             -10.418727              -1.546303      sight
# 2               2.713349               5.346510      sight
# 3               4.658481               4.467498      sight
# 4               7.941022               3.130614      sight
#
#              SEED_WORD                                  test  freq  \
# 0     ('look', 'NOUN')     [('old', 'ADJ'), ('man', 'NOUN')]   370
# 1   ('looked', 'VERB')   [('young', 'ADJ'), ('man', 'NOUN')]   365
# 2    ('watch', 'VERB')  [('great', 'ADJ'), ('deal', 'NOUN')]   220
# 3     ('seen', 'VERB')   [('good', 'ADJ'), ('deal', 'NOUN')]   215
# 4  ('looking', 'VERB')   [('long', 'ADJ'), ('time', 'NOUN')]   207
#
#                                             SENTENCE
# 0  [('"', 'PUNCT'), ('said', 'VERB'), ('hester', ...
# 1  [('she', 'PRON'), ('looked', 'VERB'), ('at', '...
# 2  [('it', 'PRON'), ("'s", 'VERB'), ('a', 'DET'),...
# 3  [('she', 'PRON'), ('had', 'VERB'), ('seen', 'V...
# 4  [('now', 'ADV'), ('he', 'PRON'), ('could', 'VE...

# %%
# with open("final_Df.pickle", "rb") as f:
#     finalDf = pkl.load(f)

# %%
finalDf['SENTENCE'] = finalDf['SENTENCE'].str.strip("[]")
finalDf['SENTENCE'] = finalDf['SENTENCE'].apply(convert)
finalDf['SENTENCE'] = finalDf['SENTENCE'].apply(convert2)
finalDf.head()
# Out:
#    principal component 1  principal component 2 SENSE_NAME  \
# 0              -9.943266              -0.374705      sight
# 1             -10.418727              -1.546303      sight
# 2               2.713349               5.346510      sight
# 3               4.658481               4.467498      sight
# 4               7.941022               3.130614      sight
#
#              SEED_WORD                                  test  freq  \
# 0     ('look', 'NOUN')     [('old', 'ADJ'), ('man', 'NOUN')]   370
# 1   ('looked', 'VERB')   [('young', 'ADJ'), ('man', 'NOUN')]   365
# 2    ('watch', 'VERB')  [('great', 'ADJ'), ('deal', 'NOUN')]   220
# 3     ('seen', 'VERB')   [('good', 'ADJ'), ('deal', 'NOUN')]   215
# 4  ('looking', 'VERB')   [('long', 'ADJ'), ('time', 'NOUN')]   207
#
#                                             SENTENCE
# 0  [(", PUNCT), (said, VERB), (hester, PROPN), (,...
# 1  [(she, PRON), (looked, VERB), (at, ADP), (the,...
# 2  [(it, PRON), ("s", VERB), (a, DET), (great, AD...
# 3  [(she, PRON), (had, VERB), (seen, VERB), (a, D...
# 4  [(now, ADV), (he, PRON), (could, VERB), (not, ...

# %%
def create_string(lst):
    new_list = [val[0] for val in lst]
    return ' '.join(l + '<br>' * (n % 20 == 2) for n, l in enumerate(new_list))
finalDf['SENTENCE'] = finalDf['SENTENCE'].apply(create_string)
finalDf.head()
# Out:
#    principal component 1  principal component 2 SENSE_NAME  \
# 0              -9.943266              -0.374705      sight
# 1             -10.418727              -1.546303      sight
# 2               2.713349               5.346510      sight
# 3               4.658481               4.467498      sight
# 4               7.941022               3.130614      sight
#
#              SEED_WORD                                  test  freq  \
# 0     ('look', 'NOUN')     [('old', 'ADJ'), ('man', 'NOUN')]   370
# 1   ('looked', 'VERB')   [('young', 'ADJ'), ('man', 'NOUN')]   365
# 2    ('watch', 'VERB')  [('great', 'ADJ'), ('deal', 'NOUN')]   220
# 3     ('seen', 'VERB')   [('good', 'ADJ'), ('deal', 'NOUN')]   215
# 4  ('looking', 'VERB')   [('long', 'ADJ'), ('time', 'NOUN')]   207
#
#                                             SENTENCE
# 0  " said hester<br>  noticing the old man "s" lo...
# 1  she looked at<br> the young man "s" bare arms . "
# 2             it "s" a<br> great deal to watch her .
# 3  she had seen<br> a good deal of the gardners ;...
# 4  now he could<br> not watch tarzan  but he was ...

# %%
# with open("principalDf.pickle", 'wb') as f:
#     pkl.dump(principalDf, f)

# %%
fig = px.scatter(
            finalDf,
            color=finalDf["SENSE_NAME"],
            color_discrete_map={'sight': '#1f77b4', 'hear': '#2ca02c', 'taste': '#d62728', 'smell': '#ff7f0e', 'touch': '#9467bd'},
            x=finalDf.columns[0],
            y=finalDf.columns[1],
            hover_data=finalDf.columns[:],
            custom_data=finalDf.columns[:],
            title= "Phrase2Vec PCA - Top 200 Descriptors By Freq")
fig.update_traces(marker=dict(size=10,))
fig.write_html("phrase2vec_noun_adj_top_200_freq.html")
fig.show()
# Out:
# <div>                            <div id="2e3d8653-d678-4c7a-ba0c-647473fcfefc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2e3d8653-d678-4c7a-ba0c-647473fcfefc")) {                    Plotly.newPlot(                        "2e3d8653-d678-4c7a-ba0c-647473fcfefc",                        [{"customdata": [[-9.943266484090705, -0.37470529774914646, "sight", "('look', 'NOUN')", "[('old', 'ADJ'), ('man', 'NOUN')]", 370, "\" said hester<br>  noticing the old man \"s\" look . "], [-10.418727381785626, -1.54630325498743, "sight", "('looked', 'VERB')", "[('young', 'ADJ'), ('man', 'NOUN')]", 365, "she looked at<br> the young man \"s\" bare arms . \""], [2.7133485968213042, 5.3465103492652934, "sight", "('watch', 'VERB')", "[('great', 'ADJ'), ('deal', 'NOUN')]", 220, "it \"s\" a<br> great deal to watch her ."], [4.65848104956426, 4.467497995467384, "sight", "('seen', 'VERB')", "[('good', 'ADJ'), ('deal', 'NOUN')]", 215, "she had seen<br> a good deal of the gardners ; she and dorothy were very intimate ; college circles expected the announcement of<br> her engagement to roy any day ."], [7.941021816146946, 3.130613740953757, "sight", "('looking', 'VERB')", "[('long', 'ADJ'), ('time', 'NOUN')]", 207, "now he could<br> not watch tarzan  but he was sure that the man sat for a long time looking at him .<br> "], [-10.588358330255723, 3.1495684059123477, "sight", "('look', 'VERB')", "[('young', 'ADJ'), ('lady', 'NOUN')]", 131, "\" look at<br> that young lady with the white beads round her head  \" whispered catherine  detaching her friend from james<br> . "], [-11.49116457975024, -2.0681660735947447, "sight", "('looked', 'VERB')", "[('old', 'ADJ'), ('woman', 'NOUN')]", 94, "she looked an<br> old woman  but was young ."], [-4.342094256212942, -3.192997670585442, "sight", "('looked', 'VERB')", "[('little', 'ADJ'), ('girl', 'NOUN')]", 92, "when dorothy <br> who was an orphan  first came to her  aunt em had been so startled by the child \"s\"<br> laughter that she would scream and press her hand upon her heart whenever dorothy \"s\" merry voice reached her ears<br> ; and she still looked at the little girl with wonder that she could find anything to laugh at .<br> "], [-11.86100024859285, 0.8981291659770443, "sight", "('eye', 'NOUN')", "[('old', 'ADJ'), ('lady', 'NOUN')]", 69, "tom felt the<br> glare of the old lady \"s\" eye  though he could not see it . \""], [8.323310119608808, 8.019648474060167, "sight", "('looked', 'VERB')", "[('door', 'NOUN'), ('open', 'ADJ')]", 67, "i flung the<br> door open and looked out . "], [-8.329907108786887, 0.5446721290314139, "sight", "('looked', 'VERB')", "[('old', 'ADJ'), ('friend', 'NOUN')]", 65, "thea looked at<br> her old friend commiseratingly . \""], [-12.558679406498376, -2.580151690772958, "sight", "('seen', 'VERB')", "[('young', 'ADJ'), ('woman', 'NOUN')]", 62, "anderssen knew what<br> the outcome must be  but he had not the heart to tell jane clayton the truth  for he<br> had seen that the young woman had come to love the child almost as passionately as though it had been<br> her own flesh and blood . "], [-9.654714434304454, -1.9661155555833474, "sight", "('look', 'VERB')", "[('young', 'ADJ'), ('girl', 'NOUN')]", 57, "it is certain<br> that the young girl did look at him ."], [-10.544813254557894, 2.844981473767612, "sight", "('look', 'VERB')", "[('old', 'ADJ'), ('gentleman', 'NOUN')]", 54, "it sent a<br> pang across his heart to think how this old gentleman would look upon him when they met ; but he<br> knew what path lay straight before him  and he took it . "], [-3.89613452180852, -5.978481426274672, "sight", "('lookers', 'NOUN')", "[('young', 'ADJ'), ('men', 'NOUN')]", 53, "among these on<br> - lookers were three young men of a superior class  carrying small kna ...
